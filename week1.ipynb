# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sys

print(sys.version)
# Out:
# 3.13.5 (main, Jul 23 2025, 00:30:06) [MSC v.1944 64 bit (AMD64)]

# %%
# load in the iris dataset

df = pd.read_csv("Iris_Dataset.csv")

df.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth          Species
# 0          5.1         3.5          1.4         0.2      Iris-setosa
# 1          4.9         3.0          1.4         0.2      Iris-setosa
# 2          4.7         3.2          1.3         0.2      Iris-setosa
# 3          5.0         3.6          1.4         0.2      Iris-setosa
# 4          7.0         3.2          4.7         1.4  Iris-versicolor

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   SepalLength  12 non-null     float64
#  1   SepalWidth   12 non-null     float64
#  2   PetalLength  12 non-null     float64
#  3   PetalWidth   12 non-null     float64
#  4   Species      12 non-null     object
# dtypes: float64(4), object(1)
# memory usage: 612.0+ bytes

# %%
plt.plot(df['SepalLength'], df['SepalWidth'], 'o')
plt.show()

# %%
df.describe()
# Out:
#        SepalLength  SepalWidth  PetalLength  PetalWidth
# count    12.000000   12.000000    12.000000   12.000000
# mean      5.900000    3.075000     3.875000    1.250000
# std       0.996357    0.369582     1.981333    0.850134
# min       4.700000    2.300000     1.300000    0.200000
# 25%       4.975000    3.000000     1.400000    0.200000
# 50%       5.900000    3.150000     4.500000    1.450000
# 75%       6.600000    3.225000     5.125000    1.800000
# max       7.600000    3.600000     6.600000    2.500000

# %%
plt.hist(df['SepalLength'])
plt.show()

# %%
df.isnull().sum()
# Out:
# SepalLength    0
# SepalWidth     0
# PetalLength    0
# PetalWidth     0
# Species        0
# dtype: int64
